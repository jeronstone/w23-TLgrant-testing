# %%
import traitlets
import ipywidgets.widgets as widgets
from IPython.display import display
from jetbot import bgr8_to_jpeg
from camera import Camera

camera = Camera.instance(width=224, height=224)
 
image = widgets.Image(format='jpeg', width=224, height=224)  # this width and height doesn't necessarily have to match the camera

camera_link = traitlets.dlink((camera, 'value'), (image, 'value'), transform=bgr8_to_jpeg)

display(image)
# Out:
# Image(value=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x02\x01\x0…

# %%
from enesUtils import *

x = 2
y = 2

split, labels = split_image(camera.value, x, y)

split_imgs = npa_to_img(split)

for i in range(len(split_imgs)):
    display(split_imgs[i])
    print(labels[i])
# Out:
# <PIL.Image.Image image mode=RGB size=112x112 at 0x7EE2CFFAC8>
# 3
# <PIL.Image.Image image mode=RGB size=112x112 at 0x7EE2CFFD30>
# 1
# <PIL.Image.Image image mode=RGB size=112x112 at 0x7EE2CFFDA0>
# 4
# <PIL.Image.Image image mode=RGB size=112x112 at 0x7EE2CFFE10>
# 2

# %%
import ipywidgets
import numpy as np
import cv2

img_widgs = []
for i in range(len(split)):
    success, encoded_image = cv2.imencode('.jpg', split[i])
    im_w_swag = encoded_image.tobytes()
    img_widgs.append(widgets.Image(value = im_w_swag))

widgets.GridBox(img_widgs, layout=widgets.Layout(grid_template_columns="repeat(3, 75px)"))
# Out:
# GridBox(children=(Image(value=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x…

# %%
camera.stop()

# %%
camera.start()
